# %% [markdown]
# # TF-IDF and N-Gram Practical Implementation

# %%
# Install scikit-learn if not already
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (1.2.1)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\sujal\appdata\roaming\python\python310\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\sujal\appdata\roaming\python\python310\site-packages (from scikit-learn) (1.24.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.1.1)

# %%
# Import required libraries
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

# %% [markdown]
# ### Sample data

# %%
documents = [
    "Data science is fun",
    "I love learning data science",
    "Machine learning is a part of data science"
]

# %% [markdown]
# ### TF-IDF Vectorization (Unigrams)

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(documents)

# Convert to DataFrame for better readability
df = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names_out())
df
# Out:
#        data      fun        is  learning     love   machine        of  \
# 0  0.391484  0.66284  0.504107  0.000000  0.00000  0.000000  0.000000
# 1  0.391484  0.00000  0.000000  0.504107  0.66284  0.000000  0.000000
# 2  0.268062  0.00000  0.345179  0.345179  0.00000  0.453868  0.453868
#
#        part   science
# 0  0.000000  0.391484
# 1  0.000000  0.391484
# 2  0.453868  0.268062

# %% [markdown]
# ### TF-IDF Vectorization with Bigrams (2-grams)

# %%
bigram_vectorizer = TfidfVectorizer(ngram_range=(2, 2))
X2 = bigram_vectorizer.fit_transform(documents)
df2 = pd.DataFrame(X2.toarray(), columns=bigram_vectorizer.get_feature_names_out())
df2
# Out:
#    data science    is fun   is part  learning data  learning is  \
# 0      0.385372  0.652491  0.000000       0.000000     0.000000
# 1      0.385372  0.000000  0.000000       0.652491     0.000000
# 2      0.255374  0.000000  0.432385       0.000000     0.432385
#
#    love learning  machine learning   of data   part of  science is
# 0       0.000000          0.000000  0.000000  0.000000    0.652491
# 1       0.652491          0.000000  0.000000  0.000000    0.000000
# 2       0.000000          0.432385  0.432385  0.432385    0.000000

# %% [markdown]
# ### Custom Example 1: Unigram + Bigram Combined

# %%
combined_vectorizer = TfidfVectorizer(ngram_range=(1, 2))
X3 = combined_vectorizer.fit_transform(documents)
df3 = pd.DataFrame(X3.toarray(), columns=combined_vectorizer.get_feature_names_out())
df3
# Out:
#        data  data science       fun        is    is fun   is part  learning  \
# 0  0.274634      0.274634  0.464997  0.353642  0.464997  0.000000  0.000000
# 1  0.274634      0.274634  0.000000  0.000000  0.000000  0.000000  0.353642
# 2  0.184899      0.184899  0.000000  0.238092  0.000000  0.313062  0.238092
#
#    learning data  learning is      love  love learning   machine  \
# 0       0.000000     0.000000  0.000000       0.000000  0.000000
# 1       0.464997     0.000000  0.464997       0.464997  0.000000
# 2       0.000000     0.313062  0.000000       0.000000  0.313062
#
#    machine learning        of   of data      part   part of   science  \
# 0          0.000000  0.000000  0.000000  0.000000  0.000000  0.274634
# 1          0.000000  0.000000  0.000000  0.000000  0.000000  0.274634
# 2          0.313062  0.313062  0.313062  0.313062  0.313062  0.184899
#
#    science is
# 0    0.464997
# 1    0.000000
# 2    0.000000

# %% [markdown]
# ### Custom Example 2: Small dataset

# %%
texts = [
    "AI is the future",
    "Future of AI is bright"
]

vector = TfidfVectorizer(ngram_range=(1,2))
X4 = vector.fit_transform(texts)
df4 = pd.DataFrame(X4.toarray(), columns=vector.get_feature_names_out())
df4
# Out:
#          ai     ai is    bright    future  future of        is  is bright  \
# 0  0.317404  0.317404  0.000000  0.317404   0.000000  0.317404   0.000000
# 1  0.268446  0.268446  0.377292  0.268446   0.377292  0.268446   0.377292
#
#      is the        of     of ai       the  the future
# 0  0.446101  0.000000  0.000000  0.446101    0.446101
# 1  0.000000  0.377292  0.377292  0.000000    0.000000
